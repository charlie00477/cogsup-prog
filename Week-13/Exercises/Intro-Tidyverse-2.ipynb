# %% [markdown]
# # Introduction to `tidyverse` Round 2
# An ["opinionated" collection of R packages](https://tidyverse.org) for data science, driven by a coherent underlying design philosophy.
# These packages are meant to help you with two essential processes:
# 1. **Data clean-up and organization**: Structure should be intuitive, so that it's easy to model, manipulate, and think about the data
# 2. **Data plotting**: The grammar of graphics (Week 13)

# %%
library(tidyverse)

# %% [markdown]
# ## Data preparation

# %% [markdown]
# ### Loading the data

# %%
data <- read_csv("data/148338_220209_095045_M057814.csv", skip=2)
# Out:
# Rows: 241 Columns: 32
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (21): type, stim1, stim2, stimPos, stimFormat, feedbackIncorrect, head, ...
# dbl (11): rowNo, ITI, feedbackTime, random, ITI_ms, ITI_f, ITI_fDuration, ti...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
education_level <- data %>% pull(response) %>% first()  

data <- data %>%
    # Keep only useful columns
    select(c(rowNo, type, stim1, stim2, stimPos, trialType, response, RT)) %>%
    
    # Keep only useful rows
    filter(type != "form") %>%
    
    # Add demographic and trial-number info, turn trial type to factor
    mutate(
        education_level = education_level, # Add info
        trial_number = row_number(),
        trialType = factor(trialType, levels = c("incongruent", "congruent"))
    ) %>%
    
    # Rename trialType to trial_type
    rename(trial_type = trialType)

head(data)
# Out:
#   rowNo type stim1          stim2          stimPos       trial_type  response
# 1 190   test croissantLarge breadSmall     -341 0; 341 0 incongruent j
# 2 125   test lampSmall      shelfLarge     -235 0; 235 0 congruent   f
# 3 200   test schoolbusLarge bikeSmall      -370 0; 370 0 congruent   j
# 4 152   test orangeLarge    raspberrySmall -307 0; 307 0 congruent   j
# 5 110   test hammerLarge    ladderSmall    -156 0; 156 0 incongruent j
# 6 215   test wheelSmall     coinLarge      -300 0; 300 0 incongruent f
#   RT   education_level             trial_number
# 1  729 College or Technical School 1
# 2  625 College or Technical School 2
# 3 1477 College or Technical School 3
# 4  793 College or Technical School 4
# 5  900 College or Technical School 5
# 6  699 College or Technical School 6

# %% [markdown]
# ### Tidying the data

# %% [markdown]
# Our data is almost tidy, but we still need to do several things.

# %% [markdown]
# #### Exercise 1
# There are two columns that are uninformative. Remove them.

# %%
data <- data %>%
    mutate(rowNo=NULL, type=NULL)

head(data)
# Out:
#   stim1          stim2          stimPos       trial_type  response RT
# 1 croissantLarge breadSmall     -341 0; 341 0 incongruent j         729
# 2 lampSmall      shelfLarge     -235 0; 235 0 congruent   f         625
# 3 schoolbusLarge bikeSmall      -370 0; 370 0 congruent   j        1477
# 4 orangeLarge    raspberrySmall -307 0; 307 0 congruent   j         793
# 5 hammerLarge    ladderSmall    -156 0; 156 0 incongruent j         900
# 6 wheelSmall     coinLarge      -300 0; 300 0 incongruent f         699
#   education_level             trial_number
# 1 College or Technical School 1
# 2 College or Technical School 2
# 3 College or Technical School 3
# 4 College or Technical School 4
# 5 College or Technical School 5
# 6 College or Technical School 6

# %% [markdown]
# #### Exercise 2
# The columns `stim1` and `stim2` refer to the stimulus presented on the left and, respectively, right. Rename the columns to make them more informative.

# %%
data <- data %>%
    rename(stim_left=stim1, stim_right=stim2)

head(data)
# Out:
#   stim_left      stim_right     stimPos       trial_type  response RT
# 1 croissantLarge breadSmall     -341 0; 341 0 incongruent j         729
# 2 lampSmall      shelfLarge     -235 0; 235 0 congruent   f         625
# 3 schoolbusLarge bikeSmall      -370 0; 370 0 congruent   j        1477
# 4 orangeLarge    raspberrySmall -307 0; 307 0 congruent   j         793
# 5 hammerLarge    ladderSmall    -156 0; 156 0 incongruent j         900
# 6 wheelSmall     coinLarge      -300 0; 300 0 incongruent f         699
#   education_level             trial_number
# 1 College or Technical School 1
# 2 College or Technical School 2
# 3 College or Technical School 3
# 4 College or Technical School 4
# 5 College or Technical School 5
# 6 College or Technical School 6

# %% [markdown]
# #### Exercise 3
# Add a new column called `subject_id` and set this participant to 1.

# %%
data <- data %>%
    mutate(subject_id=1)

head(data)
# Out:
#   stim_left      stim_right     stimPos       trial_type  response RT
# 1 croissantLarge breadSmall     -341 0; 341 0 incongruent j         729
# 2 lampSmall      shelfLarge     -235 0; 235 0 congruent   f         625
# 3 schoolbusLarge bikeSmall      -370 0; 370 0 congruent   j        1477
# 4 orangeLarge    raspberrySmall -307 0; 307 0 congruent   j         793
# 5 hammerLarge    ladderSmall    -156 0; 156 0 incongruent j         900
# 6 wheelSmall     coinLarge      -300 0; 300 0 incongruent f         699
#   education_level             trial_number subject_id
# 1 College or Technical School 1            1
# 2 College or Technical School 2            1
# 3 College or Technical School 3            1
# 4 College or Technical School 4            1
# 5 College or Technical School 5            1
# 6 College or Technical School 6            1

# %% [markdown]
# #### Exercise 4
# Add a new column called `correct_side`. This column should encode the side of the correct answer (equivalently, the side of the smaller image). Use `str_detect(string, pattern)` to compute where the smaller image was on the screen and use a conditional `mutate` to fill in the values of `correct_side`.

# %%
data <- data %>%
    mutate(
    correct_side = case_when(
      str_detect(stim_left, "Small") ~ "left",
      str_detect(stim_right, "Small") ~ "right",
      TRUE                       ~ NA_character_
    )
  )
head(data)
# Out:
#   stim_left      stim_right     stimPos       trial_type  response RT
# 1 croissantLarge breadSmall     -341 0; 341 0 incongruent j         729
# 2 lampSmall      shelfLarge     -235 0; 235 0 congruent   f         625
# 3 schoolbusLarge bikeSmall      -370 0; 370 0 congruent   j        1477
# 4 orangeLarge    raspberrySmall -307 0; 307 0 congruent   j         793
# 5 hammerLarge    ladderSmall    -156 0; 156 0 incongruent j         900
# 6 wheelSmall     coinLarge      -300 0; 300 0 incongruent f         699
#   education_level             trial_number subject_id correct_side
# 1 College or Technical School 1            1          right
# 2 College or Technical School 2            1          left
# 3 College or Technical School 3            1          right
# 4 College or Technical School 4            1          right
# 5 College or Technical School 5            1          right
# 6 College or Technical School 6            1          left

# %% [markdown]
# #### Exercise 5
# Add a new column called `correct_key`. This column should be equal to `f` if the smaller image was on the left, and to `j` if the smaller image was on the right.

# %%
data <- data %>%
    mutate(
    correct_key = case_when(
      str_detect(stim_left, "Small") ~ "f",
      str_detect(stim_right, "Small") ~ "j",
      TRUE                       ~ NA_character_
    )
  )
head(data)
# Out:
#   stim_left      stim_right     stimPos       trial_type  response RT
# 1 croissantLarge breadSmall     -341 0; 341 0 incongruent j         729
# 2 lampSmall      shelfLarge     -235 0; 235 0 congruent   f         625
# 3 schoolbusLarge bikeSmall      -370 0; 370 0 congruent   j        1477
# 4 orangeLarge    raspberrySmall -307 0; 307 0 congruent   j         793
# 5 hammerLarge    ladderSmall    -156 0; 156 0 incongruent j         900
# 6 wheelSmall     coinLarge      -300 0; 300 0 incongruent f         699
#   education_level             trial_number subject_id correct_side correct_key
# 1 College or Technical School 1            1          right        j
# 2 College or Technical School 2            1          left         f
# 3 College or Technical School 3            1          right        j
# 4 College or Technical School 4            1          right        j
# 5 College or Technical School 5            1          right        j
# 6 College or Technical School 6            1          left         f

# %% [markdown]
# #### Exercise 6
# Add a new column called `correct`. This column should be equal to 1 if the participant provided a correct response, 0 otherwise.

# %%
data <- data %>%
  mutate(
    correct = case_when(
      correct_key == response ~ "1",
      correct_key != response ~ "0"
    )
  )

head(data)
# Out:
#   stim_left      stim_right     stimPos       trial_type  response RT
# 1 croissantLarge breadSmall     -341 0; 341 0 incongruent j         729
# 2 lampSmall      shelfLarge     -235 0; 235 0 congruent   f         625
# 3 schoolbusLarge bikeSmall      -370 0; 370 0 congruent   j        1477
# 4 orangeLarge    raspberrySmall -307 0; 307 0 congruent   j         793
# 5 hammerLarge    ladderSmall    -156 0; 156 0 incongruent j         900
# 6 wheelSmall     coinLarge      -300 0; 300 0 incongruent f         699
#   education_level             trial_number subject_id correct_side correct_key
# 1 College or Technical School 1            1          right        j
# 2 College or Technical School 2            1          left         f
# 3 College or Technical School 3            1          right        j
# 4 College or Technical School 4            1          right        j
# 5 College or Technical School 5            1          right        j
# 6 College or Technical School 6            1          left         f
#   correct
# 1 1
# 2 1
# 3 1
# 4 1
# 5 1
# 6 1

# %% [markdown]
# #### Exercise 7
# The experiment had 240 trials, equally divided into two blocks. Add a new column called `trial_block` that encodes this.

# %%
data <- data %>%
  mutate(
    trial_block = if_else(trial_number <= 120, "block1", "block2")
  )
head(data)
# Out:
#   stim_left      stim_right     stimPos       trial_type  response RT
# 1 croissantLarge breadSmall     -341 0; 341 0 incongruent j         729
# 2 lampSmall      shelfLarge     -235 0; 235 0 congruent   f         625
# 3 schoolbusLarge bikeSmall      -370 0; 370 0 congruent   j        1477
# 4 orangeLarge    raspberrySmall -307 0; 307 0 congruent   j         793
# 5 hammerLarge    ladderSmall    -156 0; 156 0 incongruent j         900
# 6 wheelSmall     coinLarge      -300 0; 300 0 incongruent f         699
#   education_level             trial_number subject_id correct_side correct_key
# 1 College or Technical School 1            1          right        j
# 2 College or Technical School 2            1          left         f
# 3 College or Technical School 3            1          right        j
# 4 College or Technical School 4            1          right        j
# 5 College or Technical School 5            1          right        j
# 6 College or Technical School 6            1          left         f
#   correct trial_block
# 1 1       block1
# 2 1       block1
# 3 1       block1
# 4 1       block1
# 5 1       block1
# 6 1       block1

# %% [markdown]
# #### Exercise 8
# Recode `trial_number` so that it codes the trial number within a block. Instead of going from 1 to 240, it should go from 1 to 120 twice.

# %%
data <- data %>%
  mutate(
    trial_number = if_else(
      trial_number <= 120,
      trial_number,
      trial_number - 120L
    )
  )

# %% [markdown]
# #### Exercise 9
# It is good practice to use a consistent style throughout your script. One such style is called **snake**, the standard in python, which uses only lowercase letters and underscores: `variable_name`. Another common style is **camel**, the standard in JavaScript, which uses capital letters to mark the beginning of a new word: `variableName`. Our tibble at this point uses both styles, so turn all variable names to snake case. You can use `colnames` to see the vector of column names.

# %%
data <- data %>%
    rename(stim_pos=stimPos,rt=RT)

head(data)
# Out:
#   stim_left      stim_right     stim_pos      trial_type  response rt
# 1 croissantLarge breadSmall     -341 0; 341 0 incongruent j         729
# 2 lampSmall      shelfLarge     -235 0; 235 0 congruent   f         625
# 3 schoolbusLarge bikeSmall      -370 0; 370 0 congruent   j        1477
# 4 orangeLarge    raspberrySmall -307 0; 307 0 congruent   j         793
# 5 hammerLarge    ladderSmall    -156 0; 156 0 incongruent j         900
# 6 wheelSmall     coinLarge      -300 0; 300 0 incongruent f         699
#   education_level             trial_number subject_id correct_side correct_key
# 1 College or Technical School 1            1          right        j
# 2 College or Technical School 2            1          left         f
# 3 College or Technical School 3            1          right        j
# 4 College or Technical School 4            1          right        j
# 5 College or Technical School 5            1          right        j
# 6 College or Technical School 6            1          left         f
#   correct trial_block
# 1 1       block1
# 2 1       block1
# 3 1       block1
# 4 1       block1
# 5 1       block1
# 6 1       block1

# %% [markdown]
# #### Exercise 10
# Using `select`, reorder the columns such that participant information comes first, followed by trial block and number, followed by trial info.

# %%
data %>% colnames()

data <- data %>%
  select(subject_id, education_level,trial_block, trial_number, trial_type,
  stim_left, stim_right, stim_pos, correct_side, correct_key, correct, response, rt
  )
head(data)
# Out:
#  [1] "stim_left"       "stim_right"      "stim_pos"        "trial_type"
#  [5] "response"        "rt"              "education_level" "trial_number"
#  [9] "subject_id"      "correct_side"    "correct_key"     "correct"
# [13] "trial_block"
#   subject_id education_level             trial_block trial_number trial_type
# 1 1          College or Technical School block1      1            incongruent
# 2 1          College or Technical School block1      2            congruent
# 3 1          College or Technical School block1      3            congruent
# 4 1          College or Technical School block1      4            congruent
# 5 1          College or Technical School block1      5            incongruent
# 6 1          College or Technical School block1      6            incongruent
#   stim_left      stim_right     stim_pos      correct_side correct_key correct
# 1 croissantLarge breadSmall     -341 0; 341 0 right        j           1
# 2 lampSmall      shelfLarge     -235 0; 235 0 left         f           1
# 3 schoolbusLarge bikeSmall      -370 0; 370 0 right        j           1
# 4 orangeLarge    raspberrySmall -307 0; 307 0 right        j           1
# 5 hammerLarge    ladderSmall    -156 0; 156 0 right        j           1
# 6 wheelSmall     coinLarge      -300 0; 300 0 left         f           1
#   response rt
# 1 j         729
# 2 f         625
# 3 j        1477
# 4 j         793
# 5 j         900
# 6 f         699

# %% [markdown]
# #### Exercise 11
# Concatenate all the commands in Exercises 1–10 into a single cell and store the output in a variable called `tidy_data`.

# %%
names(data)
# Out:
#  [1] "rowNo"           "type"            "stim1"           "stim2"
#  [5] "stimPos"         "trial_type"      "response"        "RT"
#  [9] "education_level" "trial_number"

# %%
tidy_data <- data %>%
  mutate(rowNo = NULL, type = NULL) %>%
  
  rename(stim_left = stim1,
         stim_right = stim2) %>%
  
  mutate(subject_id = 1) %>%
  
  mutate(
    correct_side = case_when(
      str_detect(stim_left, "Small")  ~ "left",
      str_detect(stim_right, "Small") ~ "right",
      TRUE                            ~ NA_character_
    )
  ) %>%
  
  mutate(
    correct_key = case_when(
      str_detect(stim_left, "Small")  ~ "f",
      str_detect(stim_right, "Small") ~ "j",
      TRUE                            ~ NA_character_
    )
  ) %>%

  mutate(
    correct = case_when(
      correct_key == response ~ "1",
      correct_key != response ~ "0"
    )
  ) %>%
  mutate(
    correct = as.numeric(correct)) %>%

  mutate(
    trial_block = if_else(trial_number <= 120, "block1", "block2")
  ) %>%
  
  mutate(
    trial_number = if_else(
      trial_number <= 120,
      trial_number,
      trial_number - 120L
    )
  ) %>%
  
  rename(
    stim_pos = stimPos,
    rt       = RT
  ) %>%
  
  select(
    subject_id, education_level,
    trial_block, trial_number, trial_type,
    stim_left, stim_right, stim_pos,
    correct_side, correct_key, correct,
    response, rt
  )

# %% [markdown]
# ### Summary statistics

# %%
tidy_data %>%
    summarize(rt = mean(rt), accuracy = mean(correct), error = mean(1 - correct))
# Out:
#   rt       accuracy  error
# 1 622.7542 0.9833333 0.01666667

# %%
tidy_data %>%
    mutate(avg_error = mean(1 - correct))
# Out:
#     subject_id education_level             trial_block trial_number trial_type
# 1   1          College or Technical School block1       1           incongruent
# 2   1          College or Technical School block1       2           congruent
# 3   1          College or Technical School block1       3           congruent
# 4   1          College or Technical School block1       4           congruent
# 5   1          College or Technical School block1       5           incongruent
# 6   1          College or Technical School block1       6           incongruent
# 7   1          College or Technical School block1       7           incongruent
# 8   1          College or Technical School block1       8           congruent
# 9   1          College or Technical School block1       9           congruent
# 10  1          College or Technical School block1      10           incongruent
# 11  1          College or Technical School block1      11           congruent
# 12  1          College or Technical School block1      12           incongruent
# 13  1          College or Technical School block1      13           congruent
# 14  1          College or Technical School block1      14           congruent
# 15  1          College or Technical School block1      15           incongruent
# 16  1          College or Technical School block1      16           incongruent
# 17  1          College or Technical School block1      17           incongruent
# 18  1          College or Technical School block1      18           congruent
# 19  1          College or Technical School block1      19           congruent
# 20  1          College or Technical School block1      20           congruent
# 21  1          College or Technical School block1      21           congruent
# 22  1          College or Technical School block1      22           congruent
# 23  1          College or Technical School block1      23           congruent
# 24  1          College or Technical School block1      24           incongruent
# 25  1          College or Technical School block1      25           incongruent
# 26  1          College or Technical School block1      26           incongruent
# 27  1          College or Technical School block1      27           congruent
# 28  1          College or Technical School block1      28           congruent
# 29  1          College or Technical School block1      29           congruent
# 30  1          College or Technical School block1      30           incongruent
# ⋮   ⋮          ⋮                           ⋮           ⋮            ⋮
# 211 1          College or Technical School block2       91          incongruent
# 212 1          College or Technical School block2       92          incongruent
# 213 1          College or Technical School block2       93          congruent
# 214 1          College or Technical School block2       94          incongruent
# 215 1          College or Technical School block2       95          incongruent
# 216 1          College or Technical School block2       96          congruent
# 217 1          College or Technical School block2       97          incongruent
# 218 1          College or Technical School block2       98          incongruent
# 219 1          College or Technical School block2       99          incongruent
# 220 1          College or Technical School block2      100          congruent
# 221 1          College or Technical School block2      101          congruent
# 222 1          College or Technical School block2      102          congruent
# 223 1          College or Technical School block2      103          congruent
# 224 1          College or Technical School block2      104          congruent
# 225 1          College or Technical School block2      105          incongruent
# 226 1          College or Technical School block2      106          incongruent
# 227 1          College or Technical School block2      107          congruent
# 228 1          College or Technical School block2      108          incongruent
# 229 1          College or Technical School block2      109          incongruent
# 230 1          College or Technical School block2      110          incongruent
# 231 1          College or Technical School block2      111          congruent
# 232 1          College or Technical School block2      112          congruent
# 233 1          College or Technical School block2      113          incongruent
# 234 1          College or Technical School block2      114          congruent
# 235 1          College or Technical School block2      115          incongruent
# 236 1          College or Technical School block2      116          incongruent
# 237 1          College or Technical School block2      117          incongruent
# 238 1          College or Technical School block2      118          congruent
# 239 1          College or Technical School block2      119          congruent
# 240 1          College or Technical School block2      120          congruent
#     stim_left        stim_right      stim_pos      correct_side correct_key
# 1   croissantLarge   breadSmall      -341 0; 341 0 right        j
# 2   lampSmall        shelfLarge      -235 0; 235 0 left         f
# 3   schoolbusLarge   bikeSmall       -370 0; 370 0 right        j
# 4   orangeLarge      raspberrySmall  -307 0; 307 0 right        j
# 5   hammerLarge      ladderSmall     -156 0; 156 0 right        j
# 6   wheelSmall       coinLarge       -300 0; 300 0 left         f
# 7   coconutSmall     blueberryLarge  -309 0; 309 0 left         f
# 8   pumpkinLarge     mushroomSmall   -304 0; 304 0 right        j
# 9   croissantSmall   breadLarge      -341 0; 341 0 left         f
# 10  trayLarge        bedSmall        -350 0; 350 0 right        j
# 11  lettuceLarge     oliveSmall      -365 0; 365 0 right        j
# 12  cornSmall        green beanLarge -349 0; 349 0 left         f
# 13  chilliSmall      eggplantLarge   -274 0; 274 0 left         f
# 14  kittySmall       donkeyLarge     -309 0; 309 0 left         f
# 15  apricotLarge     watermelonSmall -300 0; 300 0 right        j
# 16  cowSmall         hedgehogLarge   -358 0; 358 0 left         f
# 17  cauliflowerSmall onionLarge      -321 0; 321 0 left         f
# 18  duckSmall        zebraLarge      -311 0; 311 0 left         f
# 19  wheelbarrowSmall carLarge        -347 0; 347 0 left         f
# 20  dishwasherLarge  backpackSmall   -259 0; 259 0 right        j
# 21  chickenSmall     pandaLarge      -333 0; 333 0 left         f
# 22  parrotSmall      orangutanLarge  -207 0; 207 0 left         f
# 23  airplaneLarge    skateboardSmall -334 0; 334 0 right        j
# 24  deerSmall        frogLarge       -299 0; 299 0 left         f
# 25  giraffeSmall     antLarge        -324 0; 324 0 left         f
# 26  dolphinSmall     goldfishLarge   -341 0; 341 0 left         f
# 27  tableLarge       hairdryerSmall  -350 0; 350 0 right        j
# 28  beeSmall         sheepLarge      -321 0; 321 0 left         f
# 29  graterSmall      skyscraperLarge -220 0; 220 0 left         f
# 30  donkeySmall      kittyLarge      -317 0; 317 0 left         f
# ⋮   ⋮                ⋮               ⋮             ⋮            ⋮
# 211 orangutanSmall   parrotLarge     -198 0; 198 0 left         f
# 212 pigeonLarge      camelSmall      -250 0; 250 0 right        j
# 213 squirrelSmall    gorillaLarge    -306 0; 306 0 left         f
# 214 pineappleSmall   cherryLarge     -223 0; 223 0 left         f
# 215 lighterLarge     treeSmall       -192 0; 192 0 right        j
# 216 alligatorLarge   shrimpSmall     -337 0; 337 0 right        j
# 217 beltLarge        cannonSmall     -353 0; 353 0 right        j
# 218 ovenSmall        bootLarge       -280 0; 280 0 left         f
# 219 oliveLarge       lettuceSmall    -363 0; 363 0 right        j
# 220 treeLarge        lighterSmall    -208 0; 208 0 right        j
# 221 cannonLarge      beltSmall       -353 0; 353 0 right        j
# 222 ovenLarge        bootSmall       -273 0; 273 0 right        j
# 223 sheepLarge       beeSmall        -321 0; 321 0 right        j
# 224 backpackSmall    dishwasherLarge -259 0; 259 0 left         f
# 225 scissorsLarge    trunkSmall      -198 0; 198 0 right        j
# 226 cannonSmall      beltLarge       -353 0; 353 0 left         f
# 227 plumSmall        melonLarge      -330 0; 330 0 left         f
# 228 lettuceSmall     oliveLarge      -363 0; 363 0 left         f
# 229 tigerSmall       rabbitLarge     -306 0; 306 0 left         f
# 230 houseLarge       leafSmall       -337 0; 337 0 right        j
# 231 lizardSmall      rhinoLarge      -369 0; 369 0 left         f
# 232 butterflySmall   elephantLarge   -322 0; 322 0 left         f
# 233 treeSmall        lighterLarge    -192 0; 192 0 left         f
# 234 elephantLarge    butterflySmall  -322 0; 322 0 right        j
# 235 gorillaSmall     squirrelLarge   -306 0; 306 0 left         f
# 236 schoolbusSmall   bikeLarge       -366 0; 366 0 left         f
# 237 orangeSmall      raspberryLarge  -308 0; 308 0 left         f
# 238 helicopterLarge  tricycleSmall   -353 0; 353 0 right        j
# 239 scissorsSmall    trunkLarge      -215 0; 215 0 left         f
# 240 oliveSmall       lettuceLarge    -365 0; 365 0 left         f
#     correct response rt   avg_error
# 1   1       j         729 0.01666667
# 2   1       f         625 0.01666667
# 3   1       j        1477 0.01666667
# 4   1       j         793 0.01666667
# 5   1       j         900 0.01666667
# 6   1       f         699 0.01666667
# 7   1       f         752 0.01666667
# 8   1       j         567 0.01666667
# 9   1       f         556 0.01666667
# 10  1       j         801 0.01666667
# 11  1       j         564 0.01666667
# 12  1       f         597 0.01666667
# 13  1       f         534 0.01666667
# 14  1       f         436 0.01666667
# 15  1       j         457 0.01666667
# 16  1       f         481 0.01666667
# 17  1       f         480 0.01666667
# 18  1       f         426 0.01666667
# 19  1       f         437 0.01666667
# 20  1       j         606 0.01666667
# 21  1       f         460 0.01666667
# 22  1       f         454 0.01666667
# 23  1       j         614 0.01666667
# 24  1       f         490 0.01666667
# 25  1       f        1037 0.01666667
# 26  1       f         485 0.01666667
# 27  1       j         493 0.01666667
# 28  1       f         428 0.01666667
# 29  1       f         501 0.01666667
# 30  1       f         990 0.01666667
# ⋮   ⋮       ⋮        ⋮    ⋮
# 211 1       f         808 0.01666667
# 212 1       j         957 0.01666667
# 213 1       f         540 0.01666667
# 214 1       f         404 0.01666667
# 215 1       j         586 0.01666667
# 216 1       j         560 0.01666667
# 217 1       j        1199 0.01666667
# 218 1       f         478 0.01666667
# 219 1       j        1407 0.01666667
# 220 1       j         547 0.01666667
# 221 1       j         522 0.01666667
# 222 1       j         498 0.01666667
# 223 1       j         490 0.01666667
# 224 1       f         437 0.01666667
# 225 1       j         727 0.01666667
# 226 1       f         523 0.01666667
# 227 1       f         447 0.01666667
# 228 1       f         416 0.01666667
# 229 1       f         455 0.01666667
# 230 1       j         518 0.01666667
# 231 1       f         458 0.01666667
# 232 1       f         433 0.01666667
# 233 1       f         429 0.01666667
# 234 1       j         476 0.01666667
# 235 1       f         456 0.01666667
# 236 1       f         672 0.01666667
# 237 1       f         357 0.01666667
# 238 1       j         498 0.01666667
# 239 1       f         697 0.01666667
# 240 1       f         414 0.01666667

# %% [markdown]
# #### Exercise 12
# Using the `.by` argument in the call to `summarize`, find out if our participant showed the predicted size Stroop in reaction times and error rates.

# %%
tidy_data %>%
  summarize(
    mean_rt   = mean(rt, na.rm = TRUE),
    accuracy  = mean(correct, na.rm = TRUE),
    error     = mean(1 - correct, na.rm = TRUE),
    .by = trial_type
  )
# Out:
#   trial_type  mean_rt  accuracy  error
# 1 incongruent 698.1000 0.9666667 0.03333333
# 2 congruent   547.4083 1.0000000 0.00000000

# %% [markdown]
# #### Exercise 13
# Using a similar logic, find out if our participant also showed a SNARC effect: Was the participant faster when the small image was on the left?

# %%
tidy_data %>%
  summarize(
    mean_rt   = mean(rt, na.rm = TRUE),
    .by = correct_side
  )
# Out:
#   correct_side mean_rt
# 1 right        632.7333
# 2 left         612.7750

# %% [markdown]
# #### Exercise 14
# Find out if the SNARC effect depends on trial type.

# %%
tidy_data %>%
  summarize(
    mean_rt   = mean(rt, na.rm = TRUE),
    .by = c(trial_type, correct_side)
  )
# Out:
#   trial_type  correct_side mean_rt
# 1 incongruent right        694.9167
# 2 congruent   left         524.2667
# 3 congruent   right        570.5500
# 4 incongruent left         701.2833

# %% [markdown]
# ## From a single participant to a full dataset
# We load all the 12 csv files in the 'data' folder, then apply the `read_csv` function to each of them using `map_dfr`. The `.id` argument creates a column that keeps the information from each file separate. This is equivalent to having a subject_id, if there is one .csv file per participant.

# %%
# Fetch all the files in the 'data' folder that end in .csv
raw_data <- list.files(path = 'data', pattern = ".csv$", full.names = TRUE) %>% 

  # Map the read_csv function to all of them, skipping the first 2 rows and creating a new id column called 'id' so that each file gets its own id
  # col_types = cols() just makes explicit that you want tidyverse to do its best to guess the type of each column (string, numeric, etc.)
  map_dfr(read_csv, col_types = cols(), skip = 2, .id = 'id')

# %% [markdown]
# #### Exercise 15
# Tidy the dataset exactly as we did for subject 1, while keeping the education-level information for each subject. Store it as `tidy_data`.
#
# Hint: **group** the tibble before calling `first(response)`), then follow the same steps as before to obtain a tidy dataset. Use `ungroup()` to return to the tibble to the ungrouped state. In fact, in most of the exercises that follow, you will need to use grouping wisely.
#
# ```R
# full_data <- raw_data %>%
#     mutate(education_level = first(response), .by = id) %>%
#     ...
# ```

# %%
tidy_data <- raw_data %>%
  mutate(education_level = first(response), .by = id) %>%

  select(rowNo, type, stim1, stim2, stimPos, trialType, response, RT,
         id, education_level) %>%
  filter(type != "form") %>%

  rename(
    stim_left  = stim1,
    stim_right = stim2
  ) %>%
  mutate(
    subject_id   = as.integer(id),
    trial_number = row_number(),  
    trial_type   = factor(trialType, levels = c("incongruent", "congruent"))
  ) %>%
  mutate(
    correct_side = case_when(
      str_detect(stim_left,  "Small") ~ "left",
      str_detect(stim_right, "Small") ~ "right",
      TRUE                             ~ NA_character_
    ),
    # correct_key
    correct_key = case_when(
      str_detect(stim_left,  "Small") ~ "f",
      str_detect(stim_right, "Small") ~ "j",
      TRUE                             ~ NA_character_
    ),
    correct = case_when(
      correct_key == response ~ 1L,
      correct_key != response ~ 0L
    ),
    # trial_block and trial_number within block
    trial_block  = if_else(trial_number <= 120, "block1", "block2"),
    trial_number = if_else(trial_number <= 120, trial_number, trial_number - 120L)
  ) %>%
  rename(
    stim_pos = stimPos,
    rt       = RT
  ) %>%
  select(
    subject_id, education_level,
    trial_block, trial_number, trial_type,
    stim_left, stim_right, stim_pos,
    correct_side, correct_key, correct,
    response, rt
  )

# %% [markdown]
# #### Exercise 16
# Trials where the responses were too slow or too fast should be excluded from the analysis. (Why?)
# Exclude the trials where the response is below 200 ms or higher than 1,500 ms. How many trials were excluded?

# %%
n_before <- nrow(tidy_data)

tidy_data <- tidy_data %>%
  filter(rt >= 200, rt <= 1500)

n_excluded <- n_before - nrow(tidy_data)
n_before
n_excluded
# Out:
# [1] 2880
# [1] 284

# %% [markdown]
# #### Exercise 17
# Exclude participants who didn't achieve 93% overall accuracy.
# How many subjects were excluded?

# %%
acc_by_subj <- tidy_data %>%
  summarize(
    accuracy = mean(correct, na.rm = TRUE),
    .by = subject_id
  )

good_subjects <- acc_by_subj %>%
  filter(accuracy >= 0.93) %>%
  pull(subject_id)

n_excluded_subj <- n_distinct(tidy_data$subject_id) - length(good_subjects)
n_excluded_subj
# Out:
# [1] 1

# %% [markdown]
# #### Exercise 18
# Summarize the response-time and accuracy measures by trial type to check whether there's a Stroop effect.

# %%
stroop_summary <- tidy_data %>%
  summarize(
    mean_rt  = mean(rt, na.rm = TRUE),
    accuracy = mean(correct, na.rm = TRUE),
    .by = trial_type
  )

stroop_summary
# Out:
#   trial_type  mean_rt  accuracy
# 1 incongruent 808.0141 0.9319781
# 2 congruent   702.5854 0.9901291

# %% [markdown]
# ## Changing the format of the data: `pivot_wider`, `pivot_longer`

# %% [markdown]
# #### Exercise 19: `pivot_wider`
# Compute the average Stroop effects for each participant. One column should be called `stroop_rt`, the other should be called `stroop_error`. Using `pull`, extract the reaction-time Stroop vector and plot its histogram.

# %%
by_subj_type <- tidy_data %>%
  summarize(
    mean_rt  = mean(rt, na.rm = TRUE),
    acc      = mean(correct, na.rm = TRUE),
    .by = c(subject_id, trial_type)
  )

wide <- by_subj_type %>%
  pivot_wider(
    names_from  = trial_type,
    values_from = c(mean_rt, acc)
  )

wide <- wide %>%
  mutate(
    stroop_rt    = mean_rt_incongruent - mean_rt_congruent,
    stroop_error = (1 - acc_incongruent) - (1 - acc_congruent) )

stroop_subjects <- wide %>%
  select(subject_id, stroop_rt, stroop_error)

stroop_rt_vec <- stroop_subjects %>%
  pull(stroop_rt)

stroop_subjects

hist(stroop_rt_vec,
     main = "Stroop RT effect",
     xlab = "RT difference (ms)")
# Out:
#    subject_id stroop_rt stroop_error
# 1   1         136.54929 0.03389831
# 2   2          15.50926 0.06481481
# 3   3         126.06838 0.08547009
# 4   4          95.07500 0.05000000
# 5   5         156.03347 0.10619469
# 6   6         115.42300 0.02923977
# 7   7          93.47843 0.02352941
# 8   8          41.63965 0.05939325
# 9   9         105.60823 0.01298701
# 10 10         190.25495 0.06739927
# 11 11          36.90920 0.10176613
# 12 12         208.12264 0.03773585
# Plot with title "Stroop RT effect"

# %% [markdown]
# #### Exercise 20: `pivot_longer`
# Building on the output tibble in Exercise 19, remove all columns except `id`, `stroop_rt`, and `stroop_error`, then gather the two stroop columns into a single column called `measure`. This column should take one of two values for each subject (`stroop_rt` or `stroop_error`), while the `value` column should register the respective participants' stroop effect.

# %%
long_stroop <- stroop_subjects %>%
  select(subject_id, stroop_rt, stroop_error) %>%
  pivot_longer(
    cols      = c(stroop_rt, stroop_error),
    names_to  = "measure",
    values_to = "value"
  )

long_stroop
# Out:
#    subject_id measure      value
# 1   1         stroop_rt    136.54929379
# 2   1         stroop_error   0.03389831
# 3   2         stroop_rt     15.50925926
# 4   2         stroop_error   0.06481481
# 5   3         stroop_rt    126.06837607
# 6   3         stroop_error   0.08547009
# 7   4         stroop_rt     95.07500000
# 8   4         stroop_error   0.05000000
# 9   5         stroop_rt    156.03347441
# 10  5         stroop_error   0.10619469
# 11  6         stroop_rt    115.42300195
# 12  6         stroop_error   0.02923977
# 13  7         stroop_rt     93.47843137
# 14  7         stroop_error   0.02352941
# 15  8         stroop_rt     41.63965247
# 16  8         stroop_error   0.05939325
# 17  9         stroop_rt    105.60822511
# 18  9         stroop_error   0.01298701
# 19 10         stroop_rt    190.25494505
# 20 10         stroop_error   0.06739927
# 21 11         stroop_rt     36.90920097
# 22 11         stroop_error   0.10176613
# 23 12         stroop_rt    208.12264151
# 24 12         stroop_error   0.03773585

# %% [markdown]
# ## Data plotting

# %% [markdown]
# ### Rule 1: If your data is in the tidy format (one variable per column, one observation per row), plotting with `ggplot` will be very easy.

# %% [markdown]
# ### Rule 2: No barplots.

# %% [markdown]
# ### One possible way to do it

# %%
average_data <- full_data %>% summarize(rt = mean(rt), .by = c(id, trial_type)) 

ggplot(average_data, aes(x = trial_type, y = rt, fill = trial_type)) +
  geom_boxplot(width = 0.5, alpha = 0.45) +
  geom_point(size = 2) +
  geom_line(aes(group = id), color = 'gray') +         
  stat_summary(fun.data = mean_se, linewidth = 2, shape = 21, size = 1.5) +
  labs(title = "Average reaction times by trial type (ms)", x = "Trial type", y = "") +
  theme_minimal() + 
  theme(
    legend.position = "none", 
    plot.title = element_text(face = "bold", size = 20),
    axis.title = element_text(size = 18),
    axis.text = element_text(size = 16))
# Out:
# Error: objet 'full_data' introuvable
# Traceback:
#
# 1. summarize(., rt = mean(rt), .by = c(id, trial_type))
# 2. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "objet 'full_data' introuvable", base::quote(eval(expr, envir)))
